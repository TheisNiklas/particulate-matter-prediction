# %%
import tensorflow as tf


import neptune
from neptune.integrations.tensorflow_keras import NeptuneCallback

import os

import numpy as np
import pandas as pd
from window_generator import WindowGenerator

from run_automation_utils import Params, init_model

from typing import Dict

# %%
def prep_window_generator(station_id):
    df = pd.read_feather(f"../../data/pollution/processed/interpolated/pm10/{station_id}.feather")
    df.set_index("timestamp", inplace=True)

    timestamp_s = df.index.map(pd.Timestamp.timestamp)

    day = 24 * 60 * 60
    year = (365.2425) * day

    df["Day sin"] = np.sin(timestamp_s * (2 * np.pi / day))
    df["Day cos"] = np.cos(timestamp_s * (2 * np.pi / day))
    df["Year sin"] = np.sin(timestamp_s * (2 * np.pi / year))
    df["Year cos"] = np.cos(timestamp_s * (2 * np.pi / year))
    df.reset_index(inplace=True)

    # Convert to radians.
    wd_rad = df.pop("winddirection_10m") * np.pi / 180
    df["winddirection_10m_sin"] = np.sin(wd_rad)
    df["winddirection_10m_cos"] = np.cos(wd_rad)

    return WindowGenerator(input_width=24 * 7, label_width=24, df=df.copy(), label_columns=["pm10"])

# %%
# window_generator_814 = prep_window_generator(814)
# window_generator_530 = prep_window_generator(530)
window_generator_538 = prep_window_generator(538)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # window_generator_814 = prep_window_generator(814)
#       2 # window_generator_530 = prep_window_generator(530)
# ----> 3 window_generator_538 = prep_window_generator(538)
#
# Cell In[2], line 21, in prep_window_generator(station_id)
#      18 df["winddirection_10m_sin"] = np.sin(wd_rad)
#      19 df["winddirection_10m_cos"] = np.cos(wd_rad)
# ---> 21 return WindowGenerator(input_width=24 * 7, label_width=24, shift=24, df=df.copy(), label_columns=["pm10"])
#
# File e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\src\model\window_generator.py:17, in WindowGenerator.__init__(self, input_width, label_width, shift, df, label_columns, window_step)
#      15 self.total_window_size = input_width + shift
#      16 # set datasets
# ---> 17 self.__generateWindows()
#      19 # Work out the label column indices.
#      20 self.label_columns = label_columns  # in our case pm10 or pm2.5
#
# File e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\src\model\window_generator.py:131, in WindowGenerator.__generateWindows(self, seed, train_size, val_size, test_size)
#     129     window_end = self.df.iloc[index + self.total_window_size]
#     130     if window_end["timestamp"] - window_begin["timestamp"] == pd.Timedelta(hours=self.total_window_size):
# --> 131         df_copy = self.df[index : index + (self.total_window_size)].copy().drop("timestamp", axis=1)
#     132         windows.append(df_copy)
#     134 windows_stack_train_val = tf.stack(windows[:int((train_size + val_size) * len(windows))])
#
# File e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\pandas\core\generic.py:6368, in NDFrame.copy(self, deep)
#    6258 @final
#    6259 def copy(self: NDFrameT, deep: bool_t | None = True) -> NDFrameT:
#    6260     """
#    6261     Make a copy of this object's indices and data.
#    6262
#    (...)
#    6366     dtype: object
#    6367     """
# -> 6368     data = self._mgr.copy(deep=deep)
#    6369     self._clear_item_cache()
#    6370     return self._constructor(data).__finalize__(self, method="copy")
#
# File e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\pandas\core\internals\managers.py:649, in BaseBlockManager.copy(self, deep)
#     646 else:
#     647     new_axes = list(self.axes)
# --> 649 res = self.apply("copy", deep=deep)
#     650 new_refs: list[weakref.ref | None] | None
#     651 if deep:
#
# File e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\pandas\core\internals\blocks.py:549, in Block.copy(self, deep)
#     547 values = self.values
#     548 if deep:
# --> 549     values = values.copy()
#     550 return type(self)(values, placement=self._mgr_locs, ndim=self.ndim)
#
# KeyboardInterrupt:

# %%
run_params: Dict[str, Params] = {}
# run_params["station_530_7lstmlayer"] = Params(
#     window_generator_530, lstm_layer_count=7, lstm_sizes=[32, 32, 32, 32, 32, 32, 32]
# )
run_params["station_538_7lstmlayer"] = Params(
    window_generator_538, lstm_layer_count=7, lstm_sizes=[32, 32, 32, 32, 32, 32, 32]
)

# %%
import logging

logger = logging.getLogger("run_logger")
fileHandler = logging.FileHandler("run.logs.txt")
logger.addHandler(fileHandler)

# %%
for run_id, params in run_params.items():
    logger.error("Start run: " + run_id)
    model = init_model(params)

    loss = tf.keras.losses.MeanSquaredError()
    if params.loss_function == "huber":
        loss = tf.keras.losses.huber
    model.compile(loss=loss, optimizer="Adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])

    name = params.to_name(100)
    temp_name = name
    append_index = 0
    while os.path.exists("../models/" + temp_name):
        append_index += 1
        temp_name = name + "_" + str(append_index)
    if append_index != 0:
        name += "_" + str(append_index)

    run = neptune.init_run(
        project="data-mining-team2/model-tests",
        api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI4Mzg2ZWZmYi05YzRlLTQ3ODYtOWE1NC1mNDM4OTM1ZjNlOTkifQ==",
        custom_run_id=run_id,
        name=name,
        source_files=["./model_tests.ipynb"],
    )

    run["parameters"] = params.to_dict()

    neptune_cbk = NeptuneCallback(run=run, base_namespace="training")

    try:
        for epoch_count_factor in range(1, 5):
            epoch_count = 50 * epoch_count_factor
            history = model.fit(
                params.window_generator.train,
                epochs=50,
                validation_data=params.window_generator.val,
                # callbacks=[neptune_cbk],                                                  # commented out so any further runs aren't tracked from neptune
            )

            eval_metrics = model.evaluate(params.window_generator.test, verbose=0)
            for j, metric in enumerate(eval_metrics):
                run[f"eval/epoch_{epoch_count}/{model.metrics_names[j]}"] = metric

            name = params.to_name(epoch_count)
            temp_name = name
            append_index = 0
            while os.path.exists("../models/" + temp_name):
                append_index += 1
                temp_name = name + "_" + str(append_index)
            if append_index != 0:
                name += "_" + str(append_index)

            model.save("../models/" + name, include_optimizer=False)

            run["model_names/" + str(epoch_count) + "epochs"] = name
    except Exception as e:
        logger.error(e)

        pass
    run.stop()
    logger.error("Finished run: " + run_id)
# Out:
# e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\neptune\common\warnings.py:62: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   warnings.warn(
# https://app.neptune.ai/data-mining-team2/model-tests/e/MOD-5
# e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\neptune\common\warnings.py:62: NeptuneUnsupportedType: You're attempting to log a type that is not directly supported by Neptune (<class 'window_generator.WindowGenerator'>).
#         Convert the value to a supported type, such as a string or float, or use stringify_unsupported(obj)
#         for dictionaries or collections that contain unsupported values.
#         For more, see https://docs.neptune.ai/help/value_of_unsupported_type
#   warnings.warn(
# Epoch 1/50
# 682/682 [==============================] - 21s 15ms/step - loss: 206.1052 - mean_absolute_error: 10.0551 - val_loss: 130.7104 - val_mean_absolute_error: 7.9739
# Epoch 2/50
# 682/682 [==============================] - 9s 13ms/step - loss: 131.2832 - mean_absolute_error: 8.0987 - val_loss: 131.8184 - val_mean_absolute_error: 8.2992
# Epoch 3/50
# 682/682 [==============================] - 9s 13ms/step - loss: 128.9623 - mean_absolute_error: 8.0326 - val_loss: 137.1435 - val_mean_absolute_error: 8.6315
# Epoch 4/50
# 682/682 [==============================] - 9s 13ms/step - loss: 128.4685 - mean_absolute_error: 8.0198 - val_loss: 130.8272 - val_mean_absolute_error: 7.9302
# Epoch 5/50
# 682/682 [==============================] - 9s 13ms/step - loss: 128.2346 - mean_absolute_error: 8.0340 - val_loss: 130.7465 - val_mean_absolute_error: 8.2284
# Epoch 6/50
# 682/682 [==============================] - 9s 13ms/step - loss: 122.5429 - mean_absolute_error: 7.8471 - val_loss: 123.6963 - val_mean_absolute_error: 7.9312
# Epoch 7/50
# 682/682 [==============================] - 9s 13ms/step - loss: 122.3126 - mean_absolute_error: 7.8229 - val_loss: 138.0202 - val_mean_absolute_error: 8.1170
# Epoch 8/50
# 682/682 [==============================] - 8s 12ms/step - loss: 120.8717 - mean_absolute_error: 7.7899 - val_loss: 123.9934 - val_mean_absolute_error: 7.8242
# Epoch 9/50
# 682/682 [==============================] - 9s 12ms/step - loss: 119.9092 - mean_absolute_error: 7.7661 - val_loss: 121.6001 - val_mean_absolute_error: 7.8715
# Epoch 10/50
# 682/682 [==============================] - 9s 13ms/step - loss: 118.8875 - mean_absolute_error: 7.7488 - val_loss: 132.9734 - val_mean_absolute_error: 8.6370
# Epoch 11/50
# 682/682 [==============================] - 9s 13ms/step - loss: 115.7412 - mean_absolute_error: 7.6547 - val_loss: 117.9993 - val_mean_absolute_error: 7.7644
# Epoch 12/50
# 682/682 [==============================] - 8s 12ms/step - loss: 113.9291 - mean_absolute_error: 7.5998 - val_loss: 124.0037 - val_mean_absolute_error: 8.0353
# Epoch 13/50
# 682/682 [==============================] - 9s 13ms/step - loss: 113.3915 - mean_absolute_error: 7.5809 - val_loss: 129.3705 - val_mean_absolute_error: 8.4271
# Epoch 14/50
# 682/682 [==============================] - 9s 13ms/step - loss: 112.7204 - mean_absolute_error: 7.5527 - val_loss: 121.0408 - val_mean_absolute_error: 7.9134
# Epoch 15/50
# 682/682 [==============================] - 9s 13ms/step - loss: 112.1197 - mean_absolute_error: 7.5506 - val_loss: 115.1335 - val_mean_absolute_error: 7.6286
# Epoch 16/50
# 682/682 [==============================] - 9s 14ms/step - loss: 109.9423 - mean_absolute_error: 7.4912 - val_loss: 118.7650 - val_mean_absolute_error: 7.7998
# Epoch 17/50
# 682/682 [==============================] - 9s 13ms/step - loss: 109.0514 - mean_absolute_error: 7.4573 - val_loss: 115.9825 - val_mean_absolute_error: 7.7064
# Epoch 18/50
# 682/682 [==============================] - 9s 13ms/step - loss: 108.4124 - mean_absolute_error: 7.4314 - val_loss: 113.3746 - val_mean_absolute_error: 7.5761
# Epoch 19/50
# 682/682 [==============================] - 9s 13ms/step - loss: 107.4711 - mean_absolute_error: 7.4104 - val_loss: 111.9478 - val_mean_absolute_error: 7.5208
# Epoch 20/50
# 682/682 [==============================] - 9s 13ms/step - loss: 106.4842 - mean_absolute_error: 7.3698 - val_loss: 116.1370 - val_mean_absolute_error: 7.5088
# Epoch 21/50
# 682/682 [==============================] - 9s 13ms/step - loss: 104.5199 - mean_absolute_error: 7.3113 - val_loss: 112.3271 - val_mean_absolute_error: 7.5272
# Epoch 22/50
# 682/682 [==============================] - 9s 13ms/step - loss: 103.5213 - mean_absolute_error: 7.2823 - val_loss: 108.2896 - val_mean_absolute_error: 7.3969
# Epoch 23/50
# 682/682 [==============================] - 9s 13ms/step - loss: 103.5480 - mean_absolute_error: 7.2665 - val_loss: 108.5914 - val_mean_absolute_error: 7.5116
# Epoch 24/50
# 682/682 [==============================] - 9s 13ms/step - loss: 104.3451 - mean_absolute_error: 7.3005 - val_loss: 110.3904 - val_mean_absolute_error: 7.5590
# Epoch 25/50
# 682/682 [==============================] - 9s 13ms/step - loss: 101.0798 - mean_absolute_error: 7.2073 - val_loss: 104.3303 - val_mean_absolute_error: 7.3302
# Epoch 26/50
# 682/682 [==============================] - 9s 14ms/step - loss: 100.2976 - mean_absolute_error: 7.1779 - val_loss: 106.3721 - val_mean_absolute_error: 7.3001
# Epoch 27/50
# 682/682 [==============================] - 9s 13ms/step - loss: 98.4951 - mean_absolute_error: 7.1238 - val_loss: 105.3258 - val_mean_absolute_error: 7.3409
# Epoch 28/50
# 682/682 [==============================] - 9s 13ms/step - loss: 97.6928 - mean_absolute_error: 7.0956 - val_loss: 103.4896 - val_mean_absolute_error: 7.2336
# Epoch 29/50
# 682/682 [==============================] - 10s 14ms/step - loss: 96.6073 - mean_absolute_error: 7.0580 - val_loss: 105.1430 - val_mean_absolute_error: 7.2942
# Epoch 30/50
# 682/682 [==============================] - 10s 14ms/step - loss: 95.5443 - mean_absolute_error: 7.0207 - val_loss: 101.1722 - val_mean_absolute_error: 7.1206
# Epoch 31/50
# 682/682 [==============================] - 10s 14ms/step - loss: 95.3900 - mean_absolute_error: 7.0062 - val_loss: 100.8787 - val_mean_absolute_error: 7.1388
# Epoch 32/50
# 682/682 [==============================] - 10s 14ms/step - loss: 94.9101 - mean_absolute_error: 6.9881 - val_loss: 102.5000 - val_mean_absolute_error: 7.2226
# Epoch 33/50
# 682/682 [==============================] - 10s 15ms/step - loss: 93.2245 - mean_absolute_error: 6.9366 - val_loss: 100.7473 - val_mean_absolute_error: 7.1340
# Epoch 34/50
# 682/682 [==============================] - 10s 14ms/step - loss: 92.9322 - mean_absolute_error: 6.9236 - val_loss: 101.5969 - val_mean_absolute_error: 7.2377
# Epoch 35/50
# 682/682 [==============================] - 9s 14ms/step - loss: 91.8888 - mean_absolute_error: 6.8913 - val_loss: 98.1025 - val_mean_absolute_error: 7.0072
# Epoch 36/50
# 682/682 [==============================] - 9s 13ms/step - loss: 92.7211 - mean_absolute_error: 6.8977 - val_loss: 99.9249 - val_mean_absolute_error: 7.1278
# Epoch 37/50
# 682/682 [==============================] - 9s 13ms/step - loss: 91.7040 - mean_absolute_error: 6.8695 - val_loss: 102.0219 - val_mean_absolute_error: 7.1268
# Epoch 38/50
# 682/682 [==============================] - 9s 13ms/step - loss: 89.6050 - mean_absolute_error: 6.8031 - val_loss: 98.7296 - val_mean_absolute_error: 7.0165
# Epoch 39/50
# 682/682 [==============================] - 9s 13ms/step - loss: 88.7880 - mean_absolute_error: 6.7771 - val_loss: 97.9781 - val_mean_absolute_error: 7.0901
# Epoch 40/50
# 682/682 [==============================] - 9s 14ms/step - loss: 88.6589 - mean_absolute_error: 6.7687 - val_loss: 96.3084 - val_mean_absolute_error: 7.0124
# Epoch 41/50
# 682/682 [==============================] - 9s 13ms/step - loss: 89.4715 - mean_absolute_error: 6.7821 - val_loss: 104.5247 - val_mean_absolute_error: 7.2471
# Epoch 42/50
# 682/682 [==============================] - 9s 13ms/step - loss: 87.8612 - mean_absolute_error: 6.7383 - val_loss: 102.4173 - val_mean_absolute_error: 7.1737
# Epoch 43/50
# 682/682 [==============================] - 9s 13ms/step - loss: 87.0675 - mean_absolute_error: 6.7082 - val_loss: 97.4122 - val_mean_absolute_error: 6.9960
# Epoch 44/50
# 682/682 [==============================] - 9s 14ms/step - loss: 86.1847 - mean_absolute_error: 6.6683 - val_loss: 96.2685 - val_mean_absolute_error: 6.9995
# Epoch 45/50
# 682/682 [==============================] - 9s 14ms/step - loss: 85.7874 - mean_absolute_error: 6.6598 - val_loss: 98.9961 - val_mean_absolute_error: 7.2144
# Epoch 46/50
# 682/682 [==============================] - 9s 13ms/step - loss: 84.9181 - mean_absolute_error: 6.6249 - val_loss: 94.9214 - val_mean_absolute_error: 6.9452
# Epoch 47/50
# 682/682 [==============================] - 9s 13ms/step - loss: 84.5560 - mean_absolute_error: 6.6072 - val_loss: 97.9399 - val_mean_absolute_error: 7.0927
# Epoch 48/50
# 682/682 [==============================] - 9s 13ms/step - loss: 84.3791 - mean_absolute_error: 6.5986 - val_loss: 94.2345 - val_mean_absolute_error: 6.9339
# Epoch 49/50
# 682/682 [==============================] - 9s 13ms/step - loss: 85.1655 - mean_absolute_error: 6.6142 - val_loss: 97.2838 - val_mean_absolute_error: 7.0333
# Epoch 50/50
# 682/682 [==============================] - 9s 13ms/step - loss: 83.8005 - mean_absolute_error: 6.5661 - val_loss: 98.0241 - val_mean_absolute_error: 7.0417
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_50_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_50_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# Epoch 1/50
# 682/682 [==============================] - 10s 14ms/step - loss: 83.4782 - mean_absolute_error: 6.5553 - val_loss: 93.9615 - val_mean_absolute_error: 6.9070
# Epoch 2/50
# 682/682 [==============================] - 10s 15ms/step - loss: 82.4255 - mean_absolute_error: 6.5215 - val_loss: 95.5134 - val_mean_absolute_error: 6.9977
# Epoch 3/50
# 682/682 [==============================] - 11s 16ms/step - loss: 86.1132 - mean_absolute_error: 6.6371 - val_loss: 101.6413 - val_mean_absolute_error: 7.1515
# Epoch 4/50
# 682/682 [==============================] - 11s 16ms/step - loss: 82.4889 - mean_absolute_error: 6.5056 - val_loss: 93.6582 - val_mean_absolute_error: 6.9349
# Epoch 5/50
# 682/682 [==============================] - 11s 16ms/step - loss: 81.2439 - mean_absolute_error: 6.4630 - val_loss: 94.6713 - val_mean_absolute_error: 6.9884
# Epoch 6/50
# 682/682 [==============================] - 10s 14ms/step - loss: 80.7077 - mean_absolute_error: 6.4425 - val_loss: 97.7452 - val_mean_absolute_error: 7.1482
# Epoch 7/50
# 682/682 [==============================] - 9s 14ms/step - loss: 80.9551 - mean_absolute_error: 6.4490 - val_loss: 98.1791 - val_mean_absolute_error: 6.9929
# Epoch 8/50
# 682/682 [==============================] - 9s 14ms/step - loss: 80.3632 - mean_absolute_error: 6.4276 - val_loss: 94.7563 - val_mean_absolute_error: 6.9082
# Epoch 9/50
# 682/682 [==============================] - 9s 14ms/step - loss: 80.4079 - mean_absolute_error: 6.4252 - val_loss: 95.0843 - val_mean_absolute_error: 6.9274
# Epoch 10/50
# 682/682 [==============================] - 10s 14ms/step - loss: 79.4949 - mean_absolute_error: 6.3877 - val_loss: 94.4634 - val_mean_absolute_error: 6.9768
# Epoch 11/50
# 682/682 [==============================] - 10s 15ms/step - loss: 81.7801 - mean_absolute_error: 6.4549 - val_loss: 91.8465 - val_mean_absolute_error: 6.7861
# Epoch 12/50
# 682/682 [==============================] - 10s 14ms/step - loss: 79.7633 - mean_absolute_error: 6.3903 - val_loss: 91.6829 - val_mean_absolute_error: 6.8535
# Epoch 13/50
# 682/682 [==============================] - 9s 14ms/step - loss: 78.3635 - mean_absolute_error: 6.3380 - val_loss: 93.5418 - val_mean_absolute_error: 6.8664
# Epoch 14/50
# 682/682 [==============================] - 9s 14ms/step - loss: 78.3048 - mean_absolute_error: 6.3341 - val_loss: 95.6397 - val_mean_absolute_error: 6.9787
# Epoch 15/50
# 682/682 [==============================] - 9s 14ms/step - loss: 78.7862 - mean_absolute_error: 6.3450 - val_loss: 92.5256 - val_mean_absolute_error: 6.9018
# Epoch 16/50
# 682/682 [==============================] - 9s 14ms/step - loss: 78.3861 - mean_absolute_error: 6.3357 - val_loss: 92.4609 - val_mean_absolute_error: 6.9114
# Epoch 17/50
# 682/682 [==============================] - 9s 14ms/step - loss: 77.8708 - mean_absolute_error: 6.3104 - val_loss: 91.8097 - val_mean_absolute_error: 6.8341
# Epoch 18/50
# 682/682 [==============================] - 9s 14ms/step - loss: 77.6679 - mean_absolute_error: 6.2950 - val_loss: 93.1902 - val_mean_absolute_error: 6.9265
# Epoch 19/50
# 682/682 [==============================] - 9s 14ms/step - loss: 77.5999 - mean_absolute_error: 6.2917 - val_loss: 95.5189 - val_mean_absolute_error: 6.9210
# Epoch 20/50
# 682/682 [==============================] - 10s 14ms/step - loss: 77.7550 - mean_absolute_error: 6.2965 - val_loss: 96.1538 - val_mean_absolute_error: 6.8840
# Epoch 21/50
# 682/682 [==============================] - 10s 15ms/step - loss: 78.0957 - mean_absolute_error: 6.3091 - val_loss: 92.2834 - val_mean_absolute_error: 6.8373
# Epoch 22/50
# 682/682 [==============================] - 9s 14ms/step - loss: 76.7899 - mean_absolute_error: 6.2590 - val_loss: 93.8793 - val_mean_absolute_error: 6.8401
# Epoch 23/50
# 682/682 [==============================] - 9s 14ms/step - loss: 79.4818 - mean_absolute_error: 6.3634 - val_loss: 109.5127 - val_mean_absolute_error: 7.3775
# Epoch 24/50
# 682/682 [==============================] - 10s 14ms/step - loss: 77.1580 - mean_absolute_error: 6.2785 - val_loss: 89.6531 - val_mean_absolute_error: 6.7692
# Epoch 25/50
# 682/682 [==============================] - 10s 14ms/step - loss: 75.3798 - mean_absolute_error: 6.1981 - val_loss: 90.3356 - val_mean_absolute_error: 6.7571
# Epoch 26/50
# 682/682 [==============================] - 11s 17ms/step - loss: 75.1982 - mean_absolute_error: 6.1891 - val_loss: 91.4997 - val_mean_absolute_error: 6.7843
# Epoch 27/50
# 682/682 [==============================] - 11s 16ms/step - loss: 75.8007 - mean_absolute_error: 6.2189 - val_loss: 92.7658 - val_mean_absolute_error: 6.7904
# Epoch 28/50
# 682/682 [==============================] - 10s 15ms/step - loss: 75.8108 - mean_absolute_error: 6.2089 - val_loss: 95.6772 - val_mean_absolute_error: 6.8919
# Epoch 29/50
# 682/682 [==============================] - 11s 16ms/step - loss: 76.4425 - mean_absolute_error: 6.2302 - val_loss: 89.9548 - val_mean_absolute_error: 6.7538
# Epoch 30/50
# 682/682 [==============================] - 10s 14ms/step - loss: 75.3834 - mean_absolute_error: 6.1908 - val_loss: 90.4244 - val_mean_absolute_error: 6.6978
# Epoch 31/50
# 682/682 [==============================] - 10s 14ms/step - loss: 74.9629 - mean_absolute_error: 6.1699 - val_loss: 90.8871 - val_mean_absolute_error: 6.7426
# Epoch 32/50
# 682/682 [==============================] - 9s 14ms/step - loss: 75.2423 - mean_absolute_error: 6.1792 - val_loss: 93.6079 - val_mean_absolute_error: 6.8034
# Epoch 33/50
# 682/682 [==============================] - 9s 14ms/step - loss: 75.4179 - mean_absolute_error: 6.1844 - val_loss: 91.4505 - val_mean_absolute_error: 6.7822
# Epoch 34/50
# 682/682 [==============================] - 9s 13ms/step - loss: 75.0133 - mean_absolute_error: 6.1706 - val_loss: 97.2972 - val_mean_absolute_error: 6.9419
# Epoch 35/50
# 682/682 [==============================] - 9s 13ms/step - loss: 74.6487 - mean_absolute_error: 6.1530 - val_loss: 94.2604 - val_mean_absolute_error: 6.7887
# Epoch 36/50
# 682/682 [==============================] - 9s 13ms/step - loss: 74.5684 - mean_absolute_error: 6.1496 - val_loss: 97.5100 - val_mean_absolute_error: 6.8805
# Epoch 37/50
# 682/682 [==============================] - 9s 13ms/step - loss: 74.2708 - mean_absolute_error: 6.1306 - val_loss: 91.2352 - val_mean_absolute_error: 6.6848
# Epoch 38/50
# 682/682 [==============================] - 9s 13ms/step - loss: 73.5374 - mean_absolute_error: 6.1041 - val_loss: 94.0605 - val_mean_absolute_error: 6.7820
# Epoch 39/50
# 682/682 [==============================] - 9s 13ms/step - loss: 74.7772 - mean_absolute_error: 6.1520 - val_loss: 92.6289 - val_mean_absolute_error: 6.7649
# Epoch 40/50
# 682/682 [==============================] - 9s 14ms/step - loss: 73.7093 - mean_absolute_error: 6.1109 - val_loss: 90.5561 - val_mean_absolute_error: 6.7899
# Epoch 41/50
# 682/682 [==============================] - 9s 13ms/step - loss: 74.6158 - mean_absolute_error: 6.1435 - val_loss: 95.5537 - val_mean_absolute_error: 6.9244
# Epoch 42/50
# 682/682 [==============================] - 9s 13ms/step - loss: 73.5098 - mean_absolute_error: 6.1002 - val_loss: 91.4571 - val_mean_absolute_error: 6.7517
# Epoch 43/50
# 682/682 [==============================] - 9s 13ms/step - loss: 74.2998 - mean_absolute_error: 6.1276 - val_loss: 91.1233 - val_mean_absolute_error: 6.7370
# Epoch 44/50
# 682/682 [==============================] - 9s 13ms/step - loss: 73.2984 - mean_absolute_error: 6.0861 - val_loss: 93.3948 - val_mean_absolute_error: 6.8209
# Epoch 45/50
# 682/682 [==============================] - 9s 13ms/step - loss: 73.0062 - mean_absolute_error: 6.0734 - val_loss: 92.0950 - val_mean_absolute_error: 6.7622
# Epoch 46/50
# 682/682 [==============================] - 9s 14ms/step - loss: 76.6258 - mean_absolute_error: 6.2052 - val_loss: 89.3523 - val_mean_absolute_error: 6.6815
# Epoch 47/50
# 682/682 [==============================] - 9s 13ms/step - loss: 72.7412 - mean_absolute_error: 6.0578 - val_loss: 89.2060 - val_mean_absolute_error: 6.6639
# Epoch 48/50
# 682/682 [==============================] - 9s 14ms/step - loss: 73.9064 - mean_absolute_error: 6.1026 - val_loss: 88.6507 - val_mean_absolute_error: 6.6784
# Epoch 49/50
# 682/682 [==============================] - 9s 13ms/step - loss: 72.8690 - mean_absolute_error: 6.0589 - val_loss: 93.6054 - val_mean_absolute_error: 6.8667
# Epoch 50/50
# 682/682 [==============================] - 9s 14ms/step - loss: 76.6940 - mean_absolute_error: 6.2000 - val_loss: 92.2115 - val_mean_absolute_error: 6.7568
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_100_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_100_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# Epoch 1/50
# 682/682 [==============================] - 11s 17ms/step - loss: 73.2033 - mean_absolute_error: 6.0741 - val_loss: 88.0194 - val_mean_absolute_error: 6.6225
# Epoch 2/50
# 682/682 [==============================] - 11s 16ms/step - loss: 72.0745 - mean_absolute_error: 6.0263 - val_loss: 90.5944 - val_mean_absolute_error: 6.7275
# Epoch 3/50
# 682/682 [==============================] - 11s 17ms/step - loss: 72.8443 - mean_absolute_error: 6.0524 - val_loss: 90.5267 - val_mean_absolute_error: 6.7489
# Epoch 4/50
# 682/682 [==============================] - 11s 17ms/step - loss: 72.3529 - mean_absolute_error: 6.0347 - val_loss: 90.2311 - val_mean_absolute_error: 6.6864
# Epoch 5/50
# 682/682 [==============================] - 11s 17ms/step - loss: 71.9718 - mean_absolute_error: 6.0146 - val_loss: 90.6955 - val_mean_absolute_error: 6.7577
# Epoch 6/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.7178 - mean_absolute_error: 6.0480 - val_loss: 91.0991 - val_mean_absolute_error: 6.7150
# Epoch 7/50
# 682/682 [==============================] - 12s 17ms/step - loss: 73.2290 - mean_absolute_error: 6.0739 - val_loss: 91.2236 - val_mean_absolute_error: 6.7347
# Epoch 8/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.2949 - mean_absolute_error: 6.0342 - val_loss: 88.4880 - val_mean_absolute_error: 6.6337
# Epoch 9/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.4425 - mean_absolute_error: 6.0362 - val_loss: 93.4791 - val_mean_absolute_error: 6.8345
# Epoch 10/50
# 682/682 [==============================] - 11s 17ms/step - loss: 73.8575 - mean_absolute_error: 6.0938 - val_loss: 90.0432 - val_mean_absolute_error: 6.7468
# Epoch 11/50
# 682/682 [==============================] - 12s 17ms/step - loss: 73.2398 - mean_absolute_error: 6.0658 - val_loss: 92.6700 - val_mean_absolute_error: 6.7419
# Epoch 12/50
# 682/682 [==============================] - 12s 18ms/step - loss: 71.5898 - mean_absolute_error: 5.9963 - val_loss: 88.3748 - val_mean_absolute_error: 6.6246
# Epoch 13/50
# 682/682 [==============================] - 11s 16ms/step - loss: 72.0168 - mean_absolute_error: 6.0158 - val_loss: 87.5520 - val_mean_absolute_error: 6.6070
# Epoch 14/50
# 682/682 [==============================] - 11s 17ms/step - loss: 71.7805 - mean_absolute_error: 6.0031 - val_loss: 89.1619 - val_mean_absolute_error: 6.6519
# Epoch 15/50
# 682/682 [==============================] - 13s 19ms/step - loss: 71.2828 - mean_absolute_error: 5.9871 - val_loss: 91.2616 - val_mean_absolute_error: 6.7485
# Epoch 16/50
# 682/682 [==============================] - 11s 17ms/step - loss: 80.5216 - mean_absolute_error: 6.3240 - val_loss: 92.6189 - val_mean_absolute_error: 6.7808
# Epoch 17/50
# 682/682 [==============================] - 12s 17ms/step - loss: 74.8280 - mean_absolute_error: 6.1103 - val_loss: 87.1649 - val_mean_absolute_error: 6.5775
# Epoch 18/50
# 682/682 [==============================] - 11s 17ms/step - loss: 71.4286 - mean_absolute_error: 5.9883 - val_loss: 89.9494 - val_mean_absolute_error: 6.6411
# Epoch 19/50
# 682/682 [==============================] - 11s 17ms/step - loss: 71.5476 - mean_absolute_error: 5.9885 - val_loss: 86.4714 - val_mean_absolute_error: 6.5390
# Epoch 20/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.8163 - mean_absolute_error: 6.0298 - val_loss: 89.4017 - val_mean_absolute_error: 6.6774
# Epoch 21/50
# 682/682 [==============================] - 12s 18ms/step - loss: 72.2358 - mean_absolute_error: 6.0134 - val_loss: 87.3651 - val_mean_absolute_error: 6.5857
# Epoch 22/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.7183 - mean_absolute_error: 5.9975 - val_loss: 90.8067 - val_mean_absolute_error: 6.6629
# Epoch 23/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.3452 - mean_absolute_error: 5.9820 - val_loss: 89.1095 - val_mean_absolute_error: 6.6517
# Epoch 24/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.7351 - mean_absolute_error: 6.0340 - val_loss: 87.7307 - val_mean_absolute_error: 6.6102
# Epoch 25/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.9544 - mean_absolute_error: 5.9594 - val_loss: 88.0566 - val_mean_absolute_error: 6.6235
# Epoch 26/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.2400 - mean_absolute_error: 5.9733 - val_loss: 88.3114 - val_mean_absolute_error: 6.6154
# Epoch 27/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.0755 - mean_absolute_error: 5.9624 - val_loss: 88.3114 - val_mean_absolute_error: 6.6217
# Epoch 28/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.7359 - mean_absolute_error: 5.9942 - val_loss: 87.5957 - val_mean_absolute_error: 6.5628
# Epoch 29/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.3963 - mean_absolute_error: 6.0188 - val_loss: 85.7371 - val_mean_absolute_error: 6.5018
# Epoch 30/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.3096 - mean_absolute_error: 6.0087 - val_loss: 91.2061 - val_mean_absolute_error: 6.7516
# Epoch 31/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.2297 - mean_absolute_error: 6.0083 - val_loss: 87.9403 - val_mean_absolute_error: 6.5958
# Epoch 32/50
# 682/682 [==============================] - 11s 17ms/step - loss: 71.2877 - mean_absolute_error: 5.9765 - val_loss: 89.0736 - val_mean_absolute_error: 6.6856
# Epoch 33/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.2860 - mean_absolute_error: 5.9281 - val_loss: 85.3560 - val_mean_absolute_error: 6.4874
# Epoch 34/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.2107 - mean_absolute_error: 5.9272 - val_loss: 85.9713 - val_mean_absolute_error: 6.5274
# Epoch 35/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.4096 - mean_absolute_error: 6.0178 - val_loss: 89.5958 - val_mean_absolute_error: 6.6340
# Epoch 36/50
# 682/682 [==============================] - 12s 17ms/step - loss: 73.1360 - mean_absolute_error: 6.0496 - val_loss: 91.0366 - val_mean_absolute_error: 6.7375
# Epoch 37/50
# 682/682 [==============================] - 12s 17ms/step - loss: 73.0024 - mean_absolute_error: 6.0426 - val_loss: 91.6074 - val_mean_absolute_error: 6.7139
# Epoch 38/50
# 682/682 [==============================] - 11s 17ms/step - loss: 73.1687 - mean_absolute_error: 6.0469 - val_loss: 89.0858 - val_mean_absolute_error: 6.6738
# Epoch 39/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.5761 - mean_absolute_error: 5.9326 - val_loss: 88.7588 - val_mean_absolute_error: 6.6788
# Epoch 40/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.0951 - mean_absolute_error: 5.9152 - val_loss: 87.8936 - val_mean_absolute_error: 6.6303
# Epoch 41/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.0797 - mean_absolute_error: 5.9223 - val_loss: 86.2563 - val_mean_absolute_error: 6.5541
# Epoch 42/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.5032 - mean_absolute_error: 6.0206 - val_loss: 90.1293 - val_mean_absolute_error: 6.6626
# Epoch 43/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.9153 - mean_absolute_error: 5.9525 - val_loss: 91.1515 - val_mean_absolute_error: 6.7781
# Epoch 44/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.3937 - mean_absolute_error: 5.9404 - val_loss: 89.8102 - val_mean_absolute_error: 6.6828
# Epoch 45/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.8744 - mean_absolute_error: 5.9579 - val_loss: 87.3398 - val_mean_absolute_error: 6.5496
# Epoch 46/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.3411 - mean_absolute_error: 5.9379 - val_loss: 88.9874 - val_mean_absolute_error: 6.6513
# Epoch 47/50
# 682/682 [==============================] - 12s 17ms/step - loss: 75.7491 - mean_absolute_error: 6.1425 - val_loss: 86.3287 - val_mean_absolute_error: 6.5706
# Epoch 48/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.2010 - mean_absolute_error: 5.9714 - val_loss: 87.3892 - val_mean_absolute_error: 6.6713
# Epoch 49/50
# 682/682 [==============================] - 12s 17ms/step - loss: 69.8075 - mean_absolute_error: 5.9110 - val_loss: 85.2605 - val_mean_absolute_error: 6.5227
# Epoch 50/50
# 682/682 [==============================] - 12s 17ms/step - loss: 69.0841 - mean_absolute_error: 5.8826 - val_loss: 83.1788 - val_mean_absolute_error: 6.4730
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_150_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_150_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# Epoch 1/50
# 682/682 [==============================] - 11s 17ms/step - loss: 71.0642 - mean_absolute_error: 5.9656 - val_loss: 85.2957 - val_mean_absolute_error: 6.5437
# Epoch 2/50
# 682/682 [==============================] - 12s 18ms/step - loss: 72.0435 - mean_absolute_error: 5.9945 - val_loss: 88.9891 - val_mean_absolute_error: 6.6301
# Epoch 3/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.6855 - mean_absolute_error: 5.9450 - val_loss: 84.3916 - val_mean_absolute_error: 6.4784
# Epoch 4/50
# 682/682 [==============================] - 12s 18ms/step - loss: 71.2701 - mean_absolute_error: 5.9635 - val_loss: 87.0118 - val_mean_absolute_error: 6.5676
# Epoch 5/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.2862 - mean_absolute_error: 6.0098 - val_loss: 86.1155 - val_mean_absolute_error: 6.5680
# Epoch 6/50
# 682/682 [==============================] - 12s 17ms/step - loss: 71.7687 - mean_absolute_error: 5.9686 - val_loss: 86.1562 - val_mean_absolute_error: 6.5378
# Epoch 7/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.2096 - mean_absolute_error: 5.9079 - val_loss: 91.2690 - val_mean_absolute_error: 6.7423
# Epoch 8/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.7171 - mean_absolute_error: 5.9353 - val_loss: 90.0152 - val_mean_absolute_error: 6.6833
# Epoch 9/50
# 682/682 [==============================] - 12s 18ms/step - loss: 73.6049 - mean_absolute_error: 6.0729 - val_loss: 86.4342 - val_mean_absolute_error: 6.5789
# Epoch 10/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.6544 - mean_absolute_error: 5.9267 - val_loss: 83.6297 - val_mean_absolute_error: 6.4415
# Epoch 11/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.9840 - mean_absolute_error: 5.8767 - val_loss: 85.5899 - val_mean_absolute_error: 6.4891
# Epoch 12/50
# 682/682 [==============================] - 12s 18ms/step - loss: 71.1229 - mean_absolute_error: 5.9546 - val_loss: 85.0803 - val_mean_absolute_error: 6.4799
# Epoch 13/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.6190 - mean_absolute_error: 5.8983 - val_loss: 84.0872 - val_mean_absolute_error: 6.4757
# Epoch 14/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.7962 - mean_absolute_error: 5.9053 - val_loss: 85.7962 - val_mean_absolute_error: 6.5742
# Epoch 15/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.8647 - mean_absolute_error: 5.9053 - val_loss: 84.8311 - val_mean_absolute_error: 6.5058
# Epoch 16/50
# 682/682 [==============================] - 12s 18ms/step - loss: 71.5622 - mean_absolute_error: 5.9845 - val_loss: 86.7835 - val_mean_absolute_error: 6.6121
# Epoch 17/50
# 682/682 [==============================] - 12s 17ms/step - loss: 72.6028 - mean_absolute_error: 6.0221 - val_loss: 92.2737 - val_mean_absolute_error: 6.8046
# Epoch 18/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.3770 - mean_absolute_error: 5.9271 - val_loss: 84.5094 - val_mean_absolute_error: 6.4868
# Epoch 19/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.4366 - mean_absolute_error: 5.8927 - val_loss: 83.2259 - val_mean_absolute_error: 6.4396
# Epoch 20/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.9767 - mean_absolute_error: 5.8789 - val_loss: 85.9702 - val_mean_absolute_error: 6.5138
# Epoch 21/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.0932 - mean_absolute_error: 5.8810 - val_loss: 86.6322 - val_mean_absolute_error: 6.5257
# Epoch 22/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.6740 - mean_absolute_error: 5.8642 - val_loss: 85.1229 - val_mean_absolute_error: 6.5581
# Epoch 23/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.8887 - mean_absolute_error: 5.8729 - val_loss: 93.0163 - val_mean_absolute_error: 6.8254
# Epoch 24/50
# 682/682 [==============================] - 12s 18ms/step - loss: 72.5349 - mean_absolute_error: 6.0052 - val_loss: 87.2455 - val_mean_absolute_error: 6.5465
# Epoch 25/50
# 682/682 [==============================] - 12s 18ms/step - loss: 71.2550 - mean_absolute_error: 5.9571 - val_loss: 85.9451 - val_mean_absolute_error: 6.5290
# Epoch 26/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.1547 - mean_absolute_error: 5.8733 - val_loss: 84.5799 - val_mean_absolute_error: 6.4801
# Epoch 27/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.8626 - mean_absolute_error: 5.8706 - val_loss: 83.7998 - val_mean_absolute_error: 6.4513
# Epoch 28/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.6545 - mean_absolute_error: 5.9458 - val_loss: 85.6782 - val_mean_absolute_error: 6.5557
# Epoch 29/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.4116 - mean_absolute_error: 5.8540 - val_loss: 83.1917 - val_mean_absolute_error: 6.4130
# Epoch 30/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.8113 - mean_absolute_error: 5.8741 - val_loss: 89.4981 - val_mean_absolute_error: 6.6602
# Epoch 31/50
# 682/682 [==============================] - 12s 18ms/step - loss: 73.7144 - mean_absolute_error: 6.0682 - val_loss: 94.6103 - val_mean_absolute_error: 6.8263
# Epoch 32/50
# 682/682 [==============================] - 12s 18ms/step - loss: 73.7251 - mean_absolute_error: 6.0904 - val_loss: 84.1001 - val_mean_absolute_error: 6.4811
# Epoch 33/50
# 682/682 [==============================] - 13s 19ms/step - loss: 69.3412 - mean_absolute_error: 5.9004 - val_loss: 83.0907 - val_mean_absolute_error: 6.4405
# Epoch 34/50
# 682/682 [==============================] - 12s 18ms/step - loss: 69.2357 - mean_absolute_error: 5.8845 - val_loss: 83.7824 - val_mean_absolute_error: 6.4593
# Epoch 35/50
# 682/682 [==============================] - 12s 18ms/step - loss: 70.0264 - mean_absolute_error: 5.9170 - val_loss: 84.2547 - val_mean_absolute_error: 6.5018
# Epoch 36/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.7160 - mean_absolute_error: 5.8647 - val_loss: 83.1729 - val_mean_absolute_error: 6.4424
# Epoch 37/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.4537 - mean_absolute_error: 5.8569 - val_loss: 83.0956 - val_mean_absolute_error: 6.4194
# Epoch 38/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.0160 - mean_absolute_error: 5.8453 - val_loss: 84.0280 - val_mean_absolute_error: 6.4384
# Epoch 39/50
# 682/682 [==============================] - 12s 17ms/step - loss: 67.9047 - mean_absolute_error: 5.8375 - val_loss: 86.5607 - val_mean_absolute_error: 6.5394
# Epoch 40/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.7464 - mean_absolute_error: 5.8696 - val_loss: 84.2390 - val_mean_absolute_error: 6.4789
# Epoch 41/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.4973 - mean_absolute_error: 5.8680 - val_loss: 85.7521 - val_mean_absolute_error: 6.5438
# Epoch 42/50
# 682/682 [==============================] - 12s 18ms/step - loss: 68.5752 - mean_absolute_error: 5.8738 - val_loss: 86.6744 - val_mean_absolute_error: 6.5314
# Epoch 43/50
# 682/682 [==============================] - 12s 17ms/step - loss: 68.7531 - mean_absolute_error: 5.8811 - val_loss: 84.0789 - val_mean_absolute_error: 6.4568
# Epoch 44/50
# 682/682 [==============================] - 12s 17ms/step - loss: 70.0861 - mean_absolute_error: 5.9407 - val_loss: 87.0528 - val_mean_absolute_error: 6.6041
# Epoch 45/50
# 682/682 [==============================] - 12s 17ms/step - loss: 69.0334 - mean_absolute_error: 5.9180 - val_loss: 87.7195 - val_mean_absolute_error: 6.6516
# Epoch 46/50
# 682/682 [==============================] - 12s 18ms/step - loss: 67.4947 - mean_absolute_error: 5.8667 - val_loss: 84.0400 - val_mean_absolute_error: 6.4533
# Epoch 47/50
# 682/682 [==============================] - 12s 18ms/step - loss: 65.1372 - mean_absolute_error: 5.7663 - val_loss: 81.1135 - val_mean_absolute_error: 6.3818
# Epoch 48/50
# 682/682 [==============================] - 12s 18ms/step - loss: 62.9214 - mean_absolute_error: 5.6696 - val_loss: 93.5961 - val_mean_absolute_error: 6.8111
# Epoch 49/50
# 682/682 [==============================] - 12s 18ms/step - loss: 62.1527 - mean_absolute_error: 5.6339 - val_loss: 78.2340 - val_mean_absolute_error: 6.2348
# Epoch 50/50
# 682/682 [==============================] - 12s 18ms/step - loss: 60.9512 - mean_absolute_error: 5.5801 - val_loss: 77.2865 - val_mean_absolute_error: 6.2162
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_200_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_200_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1\assets
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/data-mining-team2/model-tests/e/MOD-5/metadata
# ERROR:run_logger:Finished run: station_538_7lstmlayer

# %% [markdown]
# ### Extend model training

# %%
model_to_load = "../models/cnn_lstm_7days_history_1days_pred_200_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4_1"
model = tf.keras.models.load_model(model_to_load)

window_generator_538 = prep_window_generator(538)

run_params: Dict[str, Params] = {}
run_params["station_538_7lstmlayer"] = Params(
    window_generator_538, lstm_layer_count=7, lstm_sizes=[32, 32, 32, 32, 32, 32, 32]
)

for run_id, params in run_params.items():
    logger.error("Start run: " + run_id)

    loss = tf.keras.losses.MeanSquaredError()
    if params.loss_function == "huber":
        loss = tf.keras.losses.huber
    model.compile(loss=loss, optimizer="Adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])

    name = params.to_name(100)
    temp_name = name
    append_index = 0
    while os.path.exists("../models/" + temp_name):
        append_index += 1
        temp_name = name + "_" + str(append_index)
    if append_index != 0:
        name += "_" + str(append_index)

    run = neptune.init_run(
        project="data-mining-team2/model-tests",
        api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI4Mzg2ZWZmYi05YzRlLTQ3ODYtOWE1NC1mNDM4OTM1ZjNlOTkifQ==",
        custom_run_id=run_id,
        name=name,
        source_files=["./model_tests.ipynb"],
    )

    run["parameters"] = params.to_dict()

    neptune_cbk = NeptuneCallback(run=run, base_namespace="training")

    try:
        for epoch_count_factor in range(1, 5):
            epoch_count = 50 * epoch_count_factor + 200
            history = model.fit(
                params.window_generator.train,
                epochs=50,
                validation_data=params.window_generator.val,
                # callbacks=[neptune_cbk],                                                                              # commented out so any further runs aren't tracked from neptune
            )

            eval_metrics = model.evaluate(params.window_generator.test, verbose=0)
            for j, metric in enumerate(eval_metrics):
                run[f"eval/epoch_{epoch_count}/{model.metrics_names[j]}"] = metric

            name = params.to_name(epoch_count)
            temp_name = name
            append_index = 0
            while os.path.exists("../models/" + temp_name):
                append_index += 1
                temp_name = name + "_" + str(append_index)
            if append_index != 0:
                name += "_" + str(append_index)

            model.save("../models/" + name, include_optimizer=False)

            run["model_names/" + str(epoch_count) + "epochs"] = name
    except Exception as e:
        logger.error(e)

        pass
    run.stop()
    logger.error("Finished run: " + run_id)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\neptune\common\warnings.py:62: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   warnings.warn(
# https://app.neptune.ai/data-mining-team2/model-tests/e/MOD-5
# e:\FHBielefeld\Master\DataMining\feinstaubprojekt-polen\.env\lib\site-packages\neptune\common\warnings.py:62: NeptuneUnsupportedType: You're attempting to log a type that is not directly supported by Neptune (<class 'window_generator.WindowGenerator'>).
#         Convert the value to a supported type, such as a string or float, or use stringify_unsupported(obj)
#         for dictionaries or collections that contain unsupported values.
#         For more, see https://docs.neptune.ai/help/value_of_unsupported_type
#   warnings.warn(
# Epoch 1/50
# 682/682 [==============================] - 21s 17ms/step - loss: 79.2443 - mean_absolute_error: 6.3842 - val_loss: 69.4435 - val_mean_absolute_error: 5.9960
# Epoch 2/50
# 682/682 [==============================] - 10s 14ms/step - loss: 75.4123 - mean_absolute_error: 6.2265 - val_loss: 68.0149 - val_mean_absolute_error: 5.9390
# Epoch 3/50
# 682/682 [==============================] - 10s 14ms/step - loss: 73.1443 - mean_absolute_error: 6.1404 - val_loss: 66.1038 - val_mean_absolute_error: 5.8696
# Epoch 4/50
# 682/682 [==============================] - 10s 14ms/step - loss: 69.7937 - mean_absolute_error: 6.0073 - val_loss: 66.6684 - val_mean_absolute_error: 5.9190
# Epoch 5/50
# 682/682 [==============================] - 10s 15ms/step - loss: 67.9602 - mean_absolute_error: 5.9484 - val_loss: 65.4471 - val_mean_absolute_error: 5.8271
# Epoch 6/50
# 682/682 [==============================] - 10s 14ms/step - loss: 67.1358 - mean_absolute_error: 5.9056 - val_loss: 65.2758 - val_mean_absolute_error: 5.8215
# Epoch 7/50
# 682/682 [==============================] - 10s 15ms/step - loss: 66.3070 - mean_absolute_error: 5.8661 - val_loss: 64.5218 - val_mean_absolute_error: 5.8079
# Epoch 8/50
# 682/682 [==============================] - 10s 15ms/step - loss: 64.5609 - mean_absolute_error: 5.8018 - val_loss: 67.2983 - val_mean_absolute_error: 5.9117
# Epoch 9/50
# 682/682 [==============================] - 10s 15ms/step - loss: 62.6733 - mean_absolute_error: 5.7209 - val_loss: 63.6633 - val_mean_absolute_error: 5.7579
# Epoch 10/50
# 682/682 [==============================] - 10s 15ms/step - loss: 62.3057 - mean_absolute_error: 5.7031 - val_loss: 65.6479 - val_mean_absolute_error: 5.8342
# Epoch 11/50
# 682/682 [==============================] - 10s 15ms/step - loss: 62.4315 - mean_absolute_error: 5.6908 - val_loss: 65.2110 - val_mean_absolute_error: 5.7990
# Epoch 12/50
# 682/682 [==============================] - 10s 15ms/step - loss: 60.2620 - mean_absolute_error: 5.6054 - val_loss: 63.6681 - val_mean_absolute_error: 5.7641
# Epoch 13/50
# 682/682 [==============================] - 10s 15ms/step - loss: 60.4254 - mean_absolute_error: 5.6047 - val_loss: 66.3398 - val_mean_absolute_error: 5.7853
# Epoch 14/50
# 682/682 [==============================] - 10s 15ms/step - loss: 58.6685 - mean_absolute_error: 5.5420 - val_loss: 67.3259 - val_mean_absolute_error: 5.9189
# Epoch 15/50
# 682/682 [==============================] - 10s 15ms/step - loss: 58.2042 - mean_absolute_error: 5.5185 - val_loss: 66.7688 - val_mean_absolute_error: 5.9070
# Epoch 16/50
# 682/682 [==============================] - 10s 15ms/step - loss: 58.0381 - mean_absolute_error: 5.5060 - val_loss: 63.8181 - val_mean_absolute_error: 5.7369
# Epoch 17/50
# 682/682 [==============================] - 10s 15ms/step - loss: 57.5476 - mean_absolute_error: 5.4843 - val_loss: 63.2503 - val_mean_absolute_error: 5.7251
# Epoch 18/50
# 682/682 [==============================] - 10s 15ms/step - loss: 60.6691 - mean_absolute_error: 5.6106 - val_loss: 63.0476 - val_mean_absolute_error: 5.6840
# Epoch 19/50
# 682/682 [==============================] - 10s 15ms/step - loss: 57.1039 - mean_absolute_error: 5.4573 - val_loss: 61.8425 - val_mean_absolute_error: 5.6500
# Epoch 20/50
# 682/682 [==============================] - 10s 15ms/step - loss: 56.3281 - mean_absolute_error: 5.4105 - val_loss: 61.1459 - val_mean_absolute_error: 5.6771
# Epoch 21/50
# 682/682 [==============================] - 10s 15ms/step - loss: 54.3503 - mean_absolute_error: 5.3268 - val_loss: 63.0322 - val_mean_absolute_error: 5.7235
# Epoch 22/50
# 682/682 [==============================] - 10s 15ms/step - loss: 54.0671 - mean_absolute_error: 5.3106 - val_loss: 65.8859 - val_mean_absolute_error: 5.8639
# Epoch 23/50
# 682/682 [==============================] - 10s 15ms/step - loss: 55.3206 - mean_absolute_error: 5.3614 - val_loss: 61.8539 - val_mean_absolute_error: 5.6636
# Epoch 24/50
# 682/682 [==============================] - 10s 15ms/step - loss: 55.4662 - mean_absolute_error: 5.3560 - val_loss: 62.1822 - val_mean_absolute_error: 5.7203
# Epoch 25/50
# 682/682 [==============================] - 10s 15ms/step - loss: 53.8581 - mean_absolute_error: 5.2960 - val_loss: 61.3162 - val_mean_absolute_error: 5.6371
# Epoch 26/50
# 682/682 [==============================] - 10s 15ms/step - loss: 53.0989 - mean_absolute_error: 5.2558 - val_loss: 67.0994 - val_mean_absolute_error: 5.8296
# Epoch 27/50
# 682/682 [==============================] - 10s 15ms/step - loss: 53.4869 - mean_absolute_error: 5.2741 - val_loss: 66.1107 - val_mean_absolute_error: 5.8157
# Epoch 28/50
# 682/682 [==============================] - 10s 15ms/step - loss: 53.1513 - mean_absolute_error: 5.2518 - val_loss: 62.3389 - val_mean_absolute_error: 5.6556
# Epoch 29/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.9061 - mean_absolute_error: 5.2005 - val_loss: 62.3988 - val_mean_absolute_error: 5.7155
# Epoch 30/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.6979 - mean_absolute_error: 5.1892 - val_loss: 61.1735 - val_mean_absolute_error: 5.6121
# Epoch 31/50
# 682/682 [==============================] - 10s 15ms/step - loss: 53.7533 - mean_absolute_error: 5.2710 - val_loss: 62.7044 - val_mean_absolute_error: 5.6751
# Epoch 32/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.7556 - mean_absolute_error: 5.1870 - val_loss: 62.1401 - val_mean_absolute_error: 5.6542
# Epoch 33/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.0992 - mean_absolute_error: 5.1554 - val_loss: 62.2305 - val_mean_absolute_error: 5.6472
# Epoch 34/50
# 682/682 [==============================] - 10s 15ms/step - loss: 50.9148 - mean_absolute_error: 5.1412 - val_loss: 64.2503 - val_mean_absolute_error: 5.7138
# Epoch 35/50
# 682/682 [==============================] - 10s 15ms/step - loss: 52.1666 - mean_absolute_error: 5.1910 - val_loss: 63.3262 - val_mean_absolute_error: 5.6959
# Epoch 36/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.3312 - mean_absolute_error: 5.1544 - val_loss: 61.8344 - val_mean_absolute_error: 5.6433
# Epoch 37/50
# 682/682 [==============================] - 10s 15ms/step - loss: 50.3518 - mean_absolute_error: 5.1088 - val_loss: 62.8735 - val_mean_absolute_error: 5.7176
# Epoch 38/50
# 682/682 [==============================] - 10s 15ms/step - loss: 50.3838 - mean_absolute_error: 5.1058 - val_loss: 70.7065 - val_mean_absolute_error: 5.9802
# Epoch 39/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.8509 - mean_absolute_error: 5.1732 - val_loss: 64.5069 - val_mean_absolute_error: 5.7339
# Epoch 40/50
# 682/682 [==============================] - 10s 15ms/step - loss: 50.1752 - mean_absolute_error: 5.0975 - val_loss: 62.8486 - val_mean_absolute_error: 5.6888
# Epoch 41/50
# 682/682 [==============================] - 10s 15ms/step - loss: 49.4086 - mean_absolute_error: 5.0564 - val_loss: 70.1781 - val_mean_absolute_error: 5.9598
# Epoch 42/50
# 682/682 [==============================] - 10s 15ms/step - loss: 52.0866 - mean_absolute_error: 5.1739 - val_loss: 64.3002 - val_mean_absolute_error: 5.7577
# Epoch 43/50
# 682/682 [==============================] - 11s 15ms/step - loss: 51.0801 - mean_absolute_error: 5.1304 - val_loss: 61.6547 - val_mean_absolute_error: 5.6626
# Epoch 44/50
# 682/682 [==============================] - 10s 15ms/step - loss: 49.4952 - mean_absolute_error: 5.0583 - val_loss: 61.6565 - val_mean_absolute_error: 5.6271
# Epoch 45/50
# 682/682 [==============================] - 10s 15ms/step - loss: 48.6156 - mean_absolute_error: 5.0110 - val_loss: 60.2620 - val_mean_absolute_error: 5.5650
# Epoch 46/50
# 682/682 [==============================] - 10s 15ms/step - loss: 51.0108 - mean_absolute_error: 5.1162 - val_loss: 61.7449 - val_mean_absolute_error: 5.6507
# Epoch 47/50
# 682/682 [==============================] - 10s 15ms/step - loss: 48.6025 - mean_absolute_error: 5.0045 - val_loss: 60.6263 - val_mean_absolute_error: 5.6111
# Epoch 48/50
# 682/682 [==============================] - 10s 15ms/step - loss: 48.1379 - mean_absolute_error: 4.9796 - val_loss: 60.9287 - val_mean_absolute_error: 5.6242
# Epoch 49/50
# 682/682 [==============================] - 10s 15ms/step - loss: 47.4992 - mean_absolute_error: 4.9530 - val_loss: 60.2316 - val_mean_absolute_error: 5.5786
# Epoch 50/50
# 682/682 [==============================] - 10s 15ms/step - loss: 48.7780 - mean_absolute_error: 5.0224 - val_loss: 63.1697 - val_mean_absolute_error: 5.7299
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_250_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_250_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# Epoch 1/50
# 682/682 [==============================] - 10s 15ms/step - loss: 49.2483 - mean_absolute_error: 5.0358 - val_loss: 60.9227 - val_mean_absolute_error: 5.6298
# Epoch 2/50
# 682/682 [==============================] - 10s 15ms/step - loss: 48.1307 - mean_absolute_error: 4.9909 - val_loss: 61.3816 - val_mean_absolute_error: 5.6624
# Epoch 3/50
# 682/682 [==============================] - 10s 15ms/step - loss: 46.8961 - mean_absolute_error: 4.9223 - val_loss: 59.2347 - val_mean_absolute_error: 5.5280
# Epoch 4/50
# 682/682 [==============================] - 10s 15ms/step - loss: 47.9874 - mean_absolute_error: 4.9709 - val_loss: 59.9604 - val_mean_absolute_error: 5.5598
# Epoch 5/50
# 682/682 [==============================] - 11s 16ms/step - loss: 48.8705 - mean_absolute_error: 5.0123 - val_loss: 60.1293 - val_mean_absolute_error: 5.5730
# Epoch 6/50
# 682/682 [==============================] - 11s 16ms/step - loss: 47.2615 - mean_absolute_error: 4.9371 - val_loss: 59.9144 - val_mean_absolute_error: 5.5921
# Epoch 7/50
# 682/682 [==============================] - 11s 15ms/step - loss: 48.1327 - mean_absolute_error: 4.9877 - val_loss: 61.5969 - val_mean_absolute_error: 5.6559
# Epoch 8/50
# 682/682 [==============================] - 11s 15ms/step - loss: 48.0504 - mean_absolute_error: 4.9787 - val_loss: 63.3104 - val_mean_absolute_error: 5.7432
# Epoch 9/50
# 682/682 [==============================] - 10s 15ms/step - loss: 46.4152 - mean_absolute_error: 4.8949 - val_loss: 60.9663 - val_mean_absolute_error: 5.6261
# Epoch 10/50
# 682/682 [==============================] - 10s 15ms/step - loss: 47.6747 - mean_absolute_error: 4.9540 - val_loss: 61.1746 - val_mean_absolute_error: 5.6163
# Epoch 11/50
# 682/682 [==============================] - 10s 15ms/step - loss: 47.0468 - mean_absolute_error: 4.9198 - val_loss: 60.1718 - val_mean_absolute_error: 5.5858
# Epoch 12/50
# 682/682 [==============================] - 11s 15ms/step - loss: 48.7692 - mean_absolute_error: 4.9996 - val_loss: 74.2096 - val_mean_absolute_error: 6.1427
# Epoch 13/50
# 682/682 [==============================] - 11s 16ms/step - loss: 47.1484 - mean_absolute_error: 4.9200 - val_loss: 59.2650 - val_mean_absolute_error: 5.5254
# Epoch 14/50
# 682/682 [==============================] - 10s 15ms/step - loss: 47.9000 - mean_absolute_error: 4.9674 - val_loss: 61.7295 - val_mean_absolute_error: 5.6113
# Epoch 15/50
# 682/682 [==============================] - 11s 17ms/step - loss: 46.5430 - mean_absolute_error: 4.8983 - val_loss: 58.2915 - val_mean_absolute_error: 5.4915
# Epoch 16/50
# 682/682 [==============================] - 11s 16ms/step - loss: 46.5364 - mean_absolute_error: 4.8853 - val_loss: 59.9525 - val_mean_absolute_error: 5.5361
# Epoch 17/50
# 682/682 [==============================] - 11s 15ms/step - loss: 46.8902 - mean_absolute_error: 4.8963 - val_loss: 60.6960 - val_mean_absolute_error: 5.5910
# Epoch 18/50
# 682/682 [==============================] - 10s 15ms/step - loss: 45.7458 - mean_absolute_error: 4.8495 - val_loss: 60.4682 - val_mean_absolute_error: 5.6063
# Epoch 19/50
# 682/682 [==============================] - 11s 16ms/step - loss: 49.3667 - mean_absolute_error: 5.0063 - val_loss: 60.4633 - val_mean_absolute_error: 5.5912
# Epoch 20/50
# 682/682 [==============================] - 11s 16ms/step - loss: 45.7820 - mean_absolute_error: 4.8511 - val_loss: 57.1710 - val_mean_absolute_error: 5.4520
# Epoch 21/50
# 682/682 [==============================] - 11s 17ms/step - loss: 44.7205 - mean_absolute_error: 4.7904 - val_loss: 57.5142 - val_mean_absolute_error: 5.4462
# Epoch 22/50
# 682/682 [==============================] - 11s 17ms/step - loss: 46.4041 - mean_absolute_error: 4.8718 - val_loss: 58.9440 - val_mean_absolute_error: 5.5032
# Epoch 23/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.6264 - mean_absolute_error: 4.7865 - val_loss: 60.7673 - val_mean_absolute_error: 5.5384
# Epoch 24/50
# 682/682 [==============================] - 11s 16ms/step - loss: 45.6157 - mean_absolute_error: 4.8346 - val_loss: 57.9939 - val_mean_absolute_error: 5.4991
# Epoch 25/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.9723 - mean_absolute_error: 4.7999 - val_loss: 60.0323 - val_mean_absolute_error: 5.5249
# Epoch 26/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.5139 - mean_absolute_error: 4.7822 - val_loss: 57.8902 - val_mean_absolute_error: 5.4636
# Epoch 27/50
# 682/682 [==============================] - 11s 16ms/step - loss: 45.3968 - mean_absolute_error: 4.8328 - val_loss: 58.1652 - val_mean_absolute_error: 5.4714
# Epoch 28/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.2799 - mean_absolute_error: 4.7751 - val_loss: 58.3716 - val_mean_absolute_error: 5.4849
# Epoch 29/50
# 682/682 [==============================] - 11s 16ms/step - loss: 45.9694 - mean_absolute_error: 4.8430 - val_loss: 68.9128 - val_mean_absolute_error: 5.9032
# Epoch 30/50
# 682/682 [==============================] - 11s 16ms/step - loss: 48.0779 - mean_absolute_error: 4.9494 - val_loss: 61.6368 - val_mean_absolute_error: 5.6333
# Epoch 31/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.6907 - mean_absolute_error: 4.7814 - val_loss: 59.2101 - val_mean_absolute_error: 5.5091
# Epoch 32/50
# 682/682 [==============================] - 11s 15ms/step - loss: 43.9692 - mean_absolute_error: 4.7442 - val_loss: 58.5267 - val_mean_absolute_error: 5.4747
# Epoch 33/50
# 682/682 [==============================] - 11s 16ms/step - loss: 43.8639 - mean_absolute_error: 4.7341 - val_loss: 58.5014 - val_mean_absolute_error: 5.4762
# Epoch 34/50
# 682/682 [==============================] - 11s 16ms/step - loss: 43.5282 - mean_absolute_error: 4.7186 - val_loss: 59.3164 - val_mean_absolute_error: 5.5143
# Epoch 35/50
# 682/682 [==============================] - 11s 15ms/step - loss: 43.4151 - mean_absolute_error: 4.7137 - val_loss: 60.1998 - val_mean_absolute_error: 5.5490
# Epoch 36/50
# 682/682 [==============================] - 10s 15ms/step - loss: 44.3109 - mean_absolute_error: 4.7621 - val_loss: 61.7012 - val_mean_absolute_error: 5.6403
# Epoch 37/50
# 682/682 [==============================] - 11s 16ms/step - loss: 45.1165 - mean_absolute_error: 4.7944 - val_loss: 60.4264 - val_mean_absolute_error: 5.5674
# Epoch 38/50
# 682/682 [==============================] - 11s 16ms/step - loss: 43.7307 - mean_absolute_error: 4.7351 - val_loss: 57.8705 - val_mean_absolute_error: 5.4514
# Epoch 39/50
# 682/682 [==============================] - 11s 16ms/step - loss: 42.9968 - mean_absolute_error: 4.6836 - val_loss: 58.3488 - val_mean_absolute_error: 5.4821
# Epoch 40/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.3484 - mean_absolute_error: 4.7540 - val_loss: 59.9095 - val_mean_absolute_error: 5.5408
# Epoch 41/50
# 682/682 [==============================] - 11s 16ms/step - loss: 43.6484 - mean_absolute_error: 4.7187 - val_loss: 62.9616 - val_mean_absolute_error: 5.6529
# Epoch 42/50
# 682/682 [==============================] - 11s 16ms/step - loss: 44.9670 - mean_absolute_error: 4.7814 - val_loss: 61.8243 - val_mean_absolute_error: 5.6223
# Epoch 43/50
# 682/682 [==============================] - 11s 17ms/step - loss: 44.2330 - mean_absolute_error: 4.7404 - val_loss: 57.6940 - val_mean_absolute_error: 5.4272
# Epoch 44/50
# 682/682 [==============================] - 11s 16ms/step - loss: 43.1511 - mean_absolute_error: 4.6929 - val_loss: 58.0021 - val_mean_absolute_error: 5.4755
# Epoch 45/50
# 682/682 [==============================] - 11s 17ms/step - loss: 49.0057 - mean_absolute_error: 4.9401 - val_loss: 58.9885 - val_mean_absolute_error: 5.4995
# Epoch 46/50
# 682/682 [==============================] - 12s 17ms/step - loss: 42.6916 - mean_absolute_error: 4.6718 - val_loss: 57.6415 - val_mean_absolute_error: 5.4106
# Epoch 47/50
# 682/682 [==============================] - 11s 16ms/step - loss: 42.0568 - mean_absolute_error: 4.6287 - val_loss: 56.6524 - val_mean_absolute_error: 5.3950
# Epoch 48/50
# 682/682 [==============================] - 11s 16ms/step - loss: 41.4864 - mean_absolute_error: 4.6042 - val_loss: 57.4816 - val_mean_absolute_error: 5.4186
# Epoch 49/50
# 682/682 [==============================] - 11s 16ms/step - loss: 42.6372 - mean_absolute_error: 4.6659 - val_loss: 58.9664 - val_mean_absolute_error: 5.4892
# Epoch 50/50
# 682/682 [==============================] - 11s 16ms/step - loss: 42.6024 - mean_absolute_error: 4.6658 - val_loss: 58.2512 - val_mean_absolute_error: 5.4620
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_300_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_300_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# Epoch 1/50
# 682/682 [==============================] - 17s 25ms/step - loss: 41.3093 - mean_absolute_error: 4.5952 - val_loss: 58.5447 - val_mean_absolute_error: 5.4534
# Epoch 2/50
# 682/682 [==============================] - 17s 26ms/step - loss: 41.2679 - mean_absolute_error: 4.5960 - val_loss: 59.8630 - val_mean_absolute_error: 5.5342
# Epoch 3/50
# 682/682 [==============================] - 19s 28ms/step - loss: 41.8986 - mean_absolute_error: 4.6263 - val_loss: 59.6709 - val_mean_absolute_error: 5.4944
# Epoch 4/50
# 682/682 [==============================] - 18s 26ms/step - loss: 40.9908 - mean_absolute_error: 4.5853 - val_loss: 59.0965 - val_mean_absolute_error: 5.4758
# Epoch 5/50
# 682/682 [==============================] - 17s 25ms/step - loss: 41.3345 - mean_absolute_error: 4.6056 - val_loss: 58.5142 - val_mean_absolute_error: 5.4066
# Epoch 6/50
# 682/682 [==============================] - 17s 25ms/step - loss: 41.1345 - mean_absolute_error: 4.5912 - val_loss: 59.7501 - val_mean_absolute_error: 5.4825
# Epoch 7/50
# 682/682 [==============================] - 17s 25ms/step - loss: 40.4493 - mean_absolute_error: 4.5553 - val_loss: 62.0823 - val_mean_absolute_error: 5.6275
# Epoch 8/50
# 682/682 [==============================] - 17s 26ms/step - loss: 49.7000 - mean_absolute_error: 4.9535 - val_loss: 61.2392 - val_mean_absolute_error: 5.5541
# Epoch 9/50
# 682/682 [==============================] - 17s 25ms/step - loss: 43.1477 - mean_absolute_error: 4.6644 - val_loss: 57.4724 - val_mean_absolute_error: 5.4212
# Epoch 10/50
# 682/682 [==============================] - 18s 26ms/step - loss: 41.5946 - mean_absolute_error: 4.5831 - val_loss: 56.8878 - val_mean_absolute_error: 5.3728
# Epoch 11/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.7311 - mean_absolute_error: 4.5019 - val_loss: 55.3159 - val_mean_absolute_error: 5.3340
# Epoch 12/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.2597 - mean_absolute_error: 4.4865 - val_loss: 56.6239 - val_mean_absolute_error: 5.3830
# Epoch 13/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.0275 - mean_absolute_error: 4.4713 - val_loss: 58.9658 - val_mean_absolute_error: 5.5063
# Epoch 14/50
# 682/682 [==============================] - 17s 25ms/step - loss: 40.1672 - mean_absolute_error: 4.5318 - val_loss: 59.0948 - val_mean_absolute_error: 5.5068
# Epoch 15/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.2293 - mean_absolute_error: 4.4899 - val_loss: 58.4390 - val_mean_absolute_error: 5.4619
# Epoch 16/50
# 682/682 [==============================] - 17s 24ms/step - loss: 41.7373 - mean_absolute_error: 4.5894 - val_loss: 59.6218 - val_mean_absolute_error: 5.4931
# Epoch 17/50
# 682/682 [==============================] - 17s 24ms/step - loss: 42.1340 - mean_absolute_error: 4.6234 - val_loss: 59.1002 - val_mean_absolute_error: 5.5054
# Epoch 18/50
# 682/682 [==============================] - 17s 24ms/step - loss: 40.5241 - mean_absolute_error: 4.5365 - val_loss: 62.1315 - val_mean_absolute_error: 5.6438
# Epoch 19/50
# 682/682 [==============================] - 17s 24ms/step - loss: 40.3986 - mean_absolute_error: 4.5338 - val_loss: 56.5264 - val_mean_absolute_error: 5.3950
# Epoch 20/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.6790 - mean_absolute_error: 4.4907 - val_loss: 58.7547 - val_mean_absolute_error: 5.5185
# Epoch 21/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.3259 - mean_absolute_error: 4.4811 - val_loss: 57.3743 - val_mean_absolute_error: 5.4386
# Epoch 22/50
# 682/682 [==============================] - 17s 25ms/step - loss: 39.1515 - mean_absolute_error: 4.4726 - val_loss: 57.3973 - val_mean_absolute_error: 5.4278
# Epoch 23/50
# 682/682 [==============================] - 17s 24ms/step - loss: 38.8753 - mean_absolute_error: 4.4558 - val_loss: 60.5091 - val_mean_absolute_error: 5.5788
# Epoch 24/50
# 682/682 [==============================] - 17s 25ms/step - loss: 38.0390 - mean_absolute_error: 4.4153 - val_loss: 57.9808 - val_mean_absolute_error: 5.4509
# Epoch 25/50
# 682/682 [==============================] - 17s 24ms/step - loss: 38.5103 - mean_absolute_error: 4.4468 - val_loss: 57.2213 - val_mean_absolute_error: 5.4158
# Epoch 26/50
# 682/682 [==============================] - 17s 25ms/step - loss: 38.4420 - mean_absolute_error: 4.4404 - val_loss: 57.5683 - val_mean_absolute_error: 5.4481
# Epoch 27/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.7452 - mean_absolute_error: 4.4097 - val_loss: 55.5314 - val_mean_absolute_error: 5.3793
# Epoch 28/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.9360 - mean_absolute_error: 4.4070 - val_loss: 56.5448 - val_mean_absolute_error: 5.3578
# Epoch 29/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.2852 - mean_absolute_error: 4.3785 - val_loss: 55.0955 - val_mean_absolute_error: 5.3396
# Epoch 30/50
# 682/682 [==============================] - 17s 24ms/step - loss: 38.3148 - mean_absolute_error: 4.4307 - val_loss: 57.8354 - val_mean_absolute_error: 5.4460
# Epoch 31/50
# 682/682 [==============================] - 17s 25ms/step - loss: 38.2432 - mean_absolute_error: 4.4317 - val_loss: 57.5557 - val_mean_absolute_error: 5.3949
# Epoch 32/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.2148 - mean_absolute_error: 4.3791 - val_loss: 56.6341 - val_mean_absolute_error: 5.3914
# Epoch 33/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.9283 - mean_absolute_error: 4.4139 - val_loss: 58.3686 - val_mean_absolute_error: 5.3845
# Epoch 34/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.5020 - mean_absolute_error: 4.3885 - val_loss: 55.4336 - val_mean_absolute_error: 5.3667
# Epoch 35/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.2402 - mean_absolute_error: 4.3226 - val_loss: 57.2000 - val_mean_absolute_error: 5.4183
# Epoch 36/50
# 682/682 [==============================] - 17s 24ms/step - loss: 35.8444 - mean_absolute_error: 4.2995 - val_loss: 58.0846 - val_mean_absolute_error: 5.4928
# Epoch 37/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.0419 - mean_absolute_error: 4.3122 - val_loss: 57.7397 - val_mean_absolute_error: 5.4391
# Epoch 38/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.0512 - mean_absolute_error: 4.3055 - val_loss: 64.5937 - val_mean_absolute_error: 5.7838
# Epoch 39/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.1572 - mean_absolute_error: 4.3248 - val_loss: 55.1808 - val_mean_absolute_error: 5.2857
# Epoch 40/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.3932 - mean_absolute_error: 4.3340 - val_loss: 55.8013 - val_mean_absolute_error: 5.3615
# Epoch 41/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.9321 - mean_absolute_error: 4.3438 - val_loss: 60.3770 - val_mean_absolute_error: 5.5680
# Epoch 42/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.5146 - mean_absolute_error: 4.3400 - val_loss: 55.8495 - val_mean_absolute_error: 5.3860
# Epoch 43/50
# 682/682 [==============================] - 17s 24ms/step - loss: 35.1244 - mean_absolute_error: 4.2631 - val_loss: 56.1135 - val_mean_absolute_error: 5.3882
# Epoch 44/50
# 682/682 [==============================] - 17s 24ms/step - loss: 35.1917 - mean_absolute_error: 4.2629 - val_loss: 59.0730 - val_mean_absolute_error: 5.4308
# Epoch 45/50
# 682/682 [==============================] - 17s 24ms/step - loss: 36.1425 - mean_absolute_error: 4.3119 - val_loss: 62.4909 - val_mean_absolute_error: 5.6224
# Epoch 46/50
# 682/682 [==============================] - 17s 24ms/step - loss: 37.2498 - mean_absolute_error: 4.3777 - val_loss: 55.3023 - val_mean_absolute_error: 5.3312
# Epoch 47/50
# 682/682 [==============================] - 17s 25ms/step - loss: 35.4628 - mean_absolute_error: 4.2706 - val_loss: 57.0411 - val_mean_absolute_error: 5.4213
# Epoch 48/50
# 682/682 [==============================] - 17s 25ms/step - loss: 35.0658 - mean_absolute_error: 4.2558 - val_loss: 58.9299 - val_mean_absolute_error: 5.4596
# Epoch 49/50
# 682/682 [==============================] - 17s 25ms/step - loss: 34.9493 - mean_absolute_error: 4.2434 - val_loss: 56.6920 - val_mean_absolute_error: 5.3912
# Epoch 50/50
# 682/682 [==============================] - 17s 25ms/step - loss: 35.5424 - mean_absolute_error: 4.2865 - val_loss: 61.4413 - val_mean_absolute_error: 5.6532
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_350_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_350_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# Epoch 1/50
# 682/682 [==============================] - 16s 23ms/step - loss: 35.6768 - mean_absolute_error: 4.3064 - val_loss: 57.0368 - val_mean_absolute_error: 5.3471
# Epoch 2/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.6355 - mean_absolute_error: 4.2225 - val_loss: 58.8629 - val_mean_absolute_error: 5.4545
# Epoch 3/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.1898 - mean_absolute_error: 4.2052 - val_loss: 55.9073 - val_mean_absolute_error: 5.3585
# Epoch 4/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.1808 - mean_absolute_error: 4.1942 - val_loss: 54.4174 - val_mean_absolute_error: 5.3068
# Epoch 5/50
# 682/682 [==============================] - 16s 24ms/step - loss: 35.4385 - mean_absolute_error: 4.2701 - val_loss: 58.5005 - val_mean_absolute_error: 5.4893
# Epoch 6/50
# 682/682 [==============================] - 16s 24ms/step - loss: 35.8298 - mean_absolute_error: 4.2960 - val_loss: 55.5302 - val_mean_absolute_error: 5.3455
# Epoch 7/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.3759 - mean_absolute_error: 4.2065 - val_loss: 62.8826 - val_mean_absolute_error: 5.6419
# Epoch 8/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.2396 - mean_absolute_error: 4.2024 - val_loss: 55.0246 - val_mean_absolute_error: 5.3139
# Epoch 9/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.0342 - mean_absolute_error: 4.1864 - val_loss: 56.8956 - val_mean_absolute_error: 5.3964
# Epoch 10/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.8049 - mean_absolute_error: 4.2098 - val_loss: 56.5805 - val_mean_absolute_error: 5.3884
# Epoch 11/50
# 682/682 [==============================] - 16s 23ms/step - loss: 37.3552 - mean_absolute_error: 4.3625 - val_loss: 56.2368 - val_mean_absolute_error: 5.3814
# Epoch 12/50
# 682/682 [==============================] - 16s 23ms/step - loss: 35.3929 - mean_absolute_error: 4.2445 - val_loss: 57.7893 - val_mean_absolute_error: 5.4433
# Epoch 13/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.2267 - mean_absolute_error: 4.1812 - val_loss: 54.8871 - val_mean_absolute_error: 5.3050
# Epoch 14/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.5292 - mean_absolute_error: 4.1479 - val_loss: 55.3214 - val_mean_absolute_error: 5.3019
# Epoch 15/50
# 682/682 [==============================] - 16s 23ms/step - loss: 33.2999 - mean_absolute_error: 4.1414 - val_loss: 55.8548 - val_mean_absolute_error: 5.3659
# Epoch 16/50
# 682/682 [==============================] - 16s 24ms/step - loss: 34.0367 - mean_absolute_error: 4.1857 - val_loss: 54.4897 - val_mean_absolute_error: 5.2988
# Epoch 17/50
# 682/682 [==============================] - 16s 24ms/step - loss: 34.2812 - mean_absolute_error: 4.1980 - val_loss: 55.1905 - val_mean_absolute_error: 5.3411
# Epoch 18/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.2203 - mean_absolute_error: 4.1389 - val_loss: 55.8563 - val_mean_absolute_error: 5.3141
# Epoch 19/50
# 682/682 [==============================] - 16s 23ms/step - loss: 34.1812 - mean_absolute_error: 4.1841 - val_loss: 55.1702 - val_mean_absolute_error: 5.3278
# Epoch 20/50
# 682/682 [==============================] - 16s 24ms/step - loss: 34.4679 - mean_absolute_error: 4.2020 - val_loss: 58.4117 - val_mean_absolute_error: 5.4041
# Epoch 21/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.9173 - mean_absolute_error: 4.1707 - val_loss: 54.5596 - val_mean_absolute_error: 5.2754
# Epoch 22/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.8222 - mean_absolute_error: 4.1114 - val_loss: 54.2153 - val_mean_absolute_error: 5.2976
# Epoch 23/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.5072 - mean_absolute_error: 4.0883 - val_loss: 55.1710 - val_mean_absolute_error: 5.3062
# Epoch 24/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.6367 - mean_absolute_error: 4.1011 - val_loss: 54.8547 - val_mean_absolute_error: 5.2967
# Epoch 25/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.7116 - mean_absolute_error: 4.1596 - val_loss: 61.4235 - val_mean_absolute_error: 5.5859
# Epoch 26/50
# 682/682 [==============================] - 16s 23ms/step - loss: 36.3990 - mean_absolute_error: 4.3055 - val_loss: 58.9241 - val_mean_absolute_error: 5.4580
# Epoch 27/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.8496 - mean_absolute_error: 4.1673 - val_loss: 57.3534 - val_mean_absolute_error: 5.3345
# Epoch 28/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.3274 - mean_absolute_error: 4.1451 - val_loss: 57.7557 - val_mean_absolute_error: 5.3244
# Epoch 29/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.2903 - mean_absolute_error: 4.0698 - val_loss: 57.5731 - val_mean_absolute_error: 5.3907
# Epoch 30/50
# 682/682 [==============================] - 16s 24ms/step - loss: 31.8591 - mean_absolute_error: 4.0485 - val_loss: 58.7353 - val_mean_absolute_error: 5.4121
# Epoch 31/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.4961 - mean_absolute_error: 4.0912 - val_loss: 57.1917 - val_mean_absolute_error: 5.3134
# Epoch 32/50
# 682/682 [==============================] - 16s 24ms/step - loss: 33.7502 - mean_absolute_error: 4.1450 - val_loss: 56.9221 - val_mean_absolute_error: 5.3397
# Epoch 33/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.6197 - mean_absolute_error: 4.0930 - val_loss: 59.4165 - val_mean_absolute_error: 5.4418
# Epoch 34/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.6056 - mean_absolute_error: 4.0966 - val_loss: 55.6670 - val_mean_absolute_error: 5.3143
# Epoch 35/50
# 682/682 [==============================] - 16s 24ms/step - loss: 34.7370 - mean_absolute_error: 4.2165 - val_loss: 59.0176 - val_mean_absolute_error: 5.4449
# Epoch 36/50
# 682/682 [==============================] - 16s 24ms/step - loss: 34.9473 - mean_absolute_error: 4.2255 - val_loss: 55.9591 - val_mean_absolute_error: 5.3045
# Epoch 37/50
# 682/682 [==============================] - 17s 24ms/step - loss: 32.3000 - mean_absolute_error: 4.0715 - val_loss: 57.0743 - val_mean_absolute_error: 5.3302
# Epoch 38/50
# 682/682 [==============================] - 17s 25ms/step - loss: 31.6709 - mean_absolute_error: 4.0289 - val_loss: 55.2299 - val_mean_absolute_error: 5.2748
# Epoch 39/50
# 682/682 [==============================] - 17s 25ms/step - loss: 32.4854 - mean_absolute_error: 4.0848 - val_loss: 55.8656 - val_mean_absolute_error: 5.2966
# Epoch 40/50
# 682/682 [==============================] - 17s 25ms/step - loss: 31.5685 - mean_absolute_error: 4.0295 - val_loss: 57.6299 - val_mean_absolute_error: 5.3208
# Epoch 41/50
# 682/682 [==============================] - 18s 26ms/step - loss: 33.2269 - mean_absolute_error: 4.1175 - val_loss: 86.2674 - val_mean_absolute_error: 6.5521
# Epoch 42/50
# 682/682 [==============================] - 17s 25ms/step - loss: 35.9295 - mean_absolute_error: 4.3092 - val_loss: 55.7014 - val_mean_absolute_error: 5.3097
# Epoch 43/50
# 682/682 [==============================] - 16s 24ms/step - loss: 37.9832 - mean_absolute_error: 4.4001 - val_loss: 59.5808 - val_mean_absolute_error: 5.4282
# Epoch 44/50
# 682/682 [==============================] - 16s 24ms/step - loss: 35.7144 - mean_absolute_error: 4.2720 - val_loss: 52.9279 - val_mean_absolute_error: 5.2094
# Epoch 45/50
# 682/682 [==============================] - 16s 24ms/step - loss: 32.1478 - mean_absolute_error: 4.0727 - val_loss: 55.1800 - val_mean_absolute_error: 5.2770
# Epoch 46/50
# 682/682 [==============================] - 16s 24ms/step - loss: 31.8596 - mean_absolute_error: 4.0315 - val_loss: 54.4167 - val_mean_absolute_error: 5.2211
# Epoch 47/50
# 682/682 [==============================] - 16s 24ms/step - loss: 31.0831 - mean_absolute_error: 3.9930 - val_loss: 55.4125 - val_mean_absolute_error: 5.3009
# Epoch 48/50
# 682/682 [==============================] - 16s 24ms/step - loss: 31.1164 - mean_absolute_error: 3.9949 - val_loss: 55.4490 - val_mean_absolute_error: 5.3056
# Epoch 49/50
# 682/682 [==============================] - 16s 24ms/step - loss: 31.1720 - mean_absolute_error: 3.9950 - val_loss: 54.8663 - val_mean_absolute_error: 5.2764
# Epoch 50/50
# 682/682 [==============================] - 16s 24ms/step - loss: 31.6795 - mean_absolute_error: 4.0317 - val_loss: 54.9759 - val_mean_absolute_error: 5.3020
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_400_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# INFO:tensorflow:Assets written to: ../models/cnn_lstm_7days_history_1days_pred_400_epochs_7lstm-layer_32,32,32,32,32,32,32_dropout-0-4\assets
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/data-mining-team2/model-tests/e/MOD-5/metadata
# ERROR:run_logger:Finished run: station_538_7lstmlayer
